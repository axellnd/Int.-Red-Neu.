# %% [markdown]
# <a href="https://colab.research.google.com/github/axellnd/Int.-Red-Neu./blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerías a utilizar
import matplotlib.pyplot as plt # generar gráficos
import numpy as np # generar arreglos
import pandas as pd # cargar conjuntos de datos externos
import sklearn.linear_model # contiene diferentes modelos de ML
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Generar conjunto de datos
np.random.seed(0)
horas_estudio = np.random.rand(100, 1) * 10
calificaciones = 2 * horas_estudio + np.random.randn(100,1) * 2

# %%
# Preprocesamiento de datos
train_data, test_data, train_labels, test_labels = train_test_split(horas_estudio, calificaciones, test_size=0.2, random_state=42)

# %%
# Seleccionar el modelo a entrenar: Regresión lineal
model = sklearn.linear_model.LinearRegression()

# %%
# Entrenamiento de modelo de Regresión Lineal
model.fit(train_data, train_labels)
# Out:
# LinearRegression()

# %%
# Realizar predicciones con el conjunto de prueba
predicciones = model.predict(test_data)

# %%
# Calcular error cuadrático medio
mse = mean_squared_error(test_labels, predicciones)
print("Error cuadrático medio:", mse)
# Out:
# Error cuadrático medio: 3.671012987885716

# %%
# Graficar modelo de regresión lineal y predicciones
plt.scatter(test_data, test_labels, color='blue')
plt.plot(test_data, predicciones, color='red')
plt.title('Modelo de Regresión Lineal')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificaciones')
plt.show()
